# %% [markdown]
# # LAB - DATA CLEANING

# %% [markdown]
# Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Read CSV file from directory

# %%
data = pd.read_csv('C:/Users/leandro/desktop/ironhack/module-1/Data-Cleaning/data/datacopy.csv')

# %% [markdown]
# Check data using head function

# %%
data.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
#Values counts in Year column
data['Year'].value_counts()
# Out:
# 2015    139
# 2011    128
# 2014    125
# 0       124
# 2013    122
#        ...
# 1742      1
# 1758      1
# 1818      1
# 1822      1
# 1595      1
# Name: Year, Length: 232, dtype: int64

# %%
# Display all columns by given year==2011
pd.set_option('display.max_columns', None)
data[(data['Year']==2011)].head()
# Out:
#       Case Number                  Date  Year        Type  Country  \
# 606    2011.12.31             31-Dec-11  2011  Unprovoked      USA
# 607  2011.12.26.R  Reported 26-Dec-2011  2011     Invalid  ANTIGUA
# 608    2011.12.25             25-Dec-11  2011  Unprovoked  ECUADOR
# 609    2011.12.23             23-Dec-11  2011  Unprovoked      USA
# 610  2011.12.21.b             21-Dec-11  2011    Provoked      USA
#
#             Area                    Location  Activity  \
# 606      Florida  Jupiter, Palm Beach County       NaN
# 607    St John's            Fort James Beach  Swimming
# 608  Santa Elena              Barand˙a Beach   Surfing
# 609      Florida            New Smyrna Beach   Surfing
# 610       Hawaii      Makahuena Point, Kauai  Canoeing
#
#                            Name Sex   Age  \
# 606                        male    M  NaN
# 607         Veron Edwards, Sr.     M  NaN
# 608  FÈlix J˙nior Lainez Trejos    M   23
# 609                 Will Futato    M   27
# ...

# %% [markdown]
# Perfom dataframe analysis
# Statistics - Shape - Size - data type

# %%
# Dataframe Statistics
data.describe()
# Out:
#               Year  original order
# count  5992.000000     5992.000000
# mean   1925.204606     2997.548899
# std     286.473712     1729.860210
# min       0.000000        2.000000
# 25%    1942.000000     1499.750000
# 50%    1975.000000     2997.500000
# 75%    2003.000000     4495.250000
# max    2016.000000     5993.000000

# %%
# Dataframe composition
d_shape=data.shape
print('Rows:',d_shape[0] , 'Columns:',d_shape[1])
# Out:
# Rows: 5992 Columns: 24

# %%
#Data type value counts
data.dtypes.value_counts()
# Out:
# object    22
# int64      2
# dtype: int64

# %%
# Data Size(Rows x Columns)
data.size
# Out:
# 143808

# %%
#data type 
data.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int64
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int64
# Unnamed: 22               object
# Unnamed: 23               object
# dtype: object

# %%
#data type Index 
data.dtypes.index
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Column names
for col in data.columns:
    print(col)
# Out:
# Case Number
# Date
# Year
# Type
# Country
# Area
# Location
# Activity
# Name
# Sex
# Age
# Injury
# Fatal (Y/N)
# Time
# Species
# Investigator or Source
# pdf
# href formula
# href
# Case Number.1
# Case Number.2
# original order
# Unnamed: 22
# Unnamed: 23

# %%
x = data.isnull().sum()
type(x)
# Out:
# pandas.core.series.Series

# %%
null_cols = data.isnull().sum()
# print(null_cols)
null_cols[null_cols > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
#Null values
data.isnull().head()
# Out:
#    Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0        False  False  False  False    False  False     False     False
# 1        False  False  False  False    False  False     False     False
# 2        False  False  False  False    False  False     False     False
# 3        False  False  False  False    False  False     False     False
# 4        False  False  False  False    False  False     False     False
#
#     Name   Sex     Age  Injury  Fatal (Y/N)   Time  Species   \
# 0  False  False  False   False        False  False      True
# 1  False  False  False   False        False  False      True
# 2  False  False  False   False        False  False      True
# 3  False  False   True   False        False   True      True
# 4  False  False   True   False        False   True     False
#
#    Investigator or Source    pdf  href formula   href  Case Number.1  \
# 0                   False  False         False  False          False
# ...

# %%
null_displ = data[(data['Year'].isnull()==True)]
null_displ.head(5)
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []

# %%
stats = data.describe().transpose()
stats.head()
# Out:
#                  count         mean          std  min      25%     50%  \
# Year            5992.0  1925.204606   286.473712  0.0  1942.00  1975.0
# original order  5992.0  2997.548899  1729.860210  2.0  1499.75  2997.5
#
#                     75%     max
# Year            2003.00  2016.0
# original order  4495.25  5993.0

# %%
stats['IQR'] = stats['75%'] - stats['25%']
stats.head()
# Out:
#                  count         mean          std  min      25%     50%  \
# Year            5992.0  1925.204606   286.473712  0.0  1942.00  1975.0
# original order  5992.0  2997.548899  1729.860210  2.0  1499.75  2997.5
#
#                     75%     max     IQR
# Year            2003.00  2016.0    61.0
# original order  4495.25  5993.0  2995.5

# %%
import numpy as np
low_variance = []

for col in data._get_numeric_data(): 
    minimum = min(data[col])
    ninety_perc = np.percentile(data[col], 50)
    if ninety_perc == minimum:
        low_variance.append(col)

print(low_variance)
print(minimum)
# Out:
# []
# 2

# %%
data.iloc[0][0]
# Out:
# '2016.09.18.c'

# %%
data['Country']
# Out:
# 0                      USA
# 1                      USA
# 2                      USA
# 3                AUSTRALIA
# 4                AUSTRALIA
#                ...
# 5987             AUSTRALIA
# 5988             AUSTRALIA
# 5989                   USA
# 5990                PANAMA
# 5991    CEYLON (SRI LANKA)
# Name: Country, Length: 5992, dtype: object

# %%
print(set(data['Country']))
# Out:
# {nan, 'CHILE', 'BRITISH NEW GUINEA', 'PACIFIC OCEAN ', 'KENYA', 'CAYMAN ISLANDS', 'CRETE', 'NEW GUINEA', 'THAILAND', 'SOUTH CHINA SEA', 'MALDIVE ISLANDS', 'NICARAGUA ', 'NEVIS', 'GUYANA', 'ITALY', 'CHINA', 'SLOVENIA', 'ARGENTINA', 'BARBADOS', 'FEDERATED STATES OF MICRONESIA', 'PALAU', 'SYRIA', 'CURACAO', 'SIERRA LEONE', 'NIGERIA', 'KIRIBATI', 'EQUATORIAL GUINEA / CAMEROON', 'SINGAPORE', 'SEYCHELLES', 'ANGOLA', 'GABON', 'IRAQ', 'MEDITERRANEAN SEA?', 'HONG KONG', 'SOUTH PACIFIC OCEAN', 'LEBANON', 'PARAGUAY', 'CENTRAL PACIFIC', 'NORTHERN MARIANA ISLANDS', 'PANAMA', 'NETHERLANDS ANTILLES', 'VIETNAM', 'MALTA', 'Coast of AFRICA', 'TUVALU', 'INDIA', 'ISRAEL', 'INDONESIA', 'BRAZIL', 'BRITISH VIRGIN ISLANDS', 'URUGUAY', 'BERMUDA', 'NORTH PACIFIC OCEAN', 'NORTHERN ARABIAN SEA', 'SOUTH AFRICA', 'JAMAICA', 'PORTUGAL', 'Between PORTUGAL & INDIA', 'JAPAN', 'NORTH ATLANTIC OCEAN', 'GUATEMALA', 'PALESTINIAN TERRITORIES', 'RED SEA', 'GHANA', 'FIJI', 'SWEDEN', 'UNITED ARAB EMIRATES (UAE)', 'EGYPT / IS
# ...

# %%
data['Case Number.1'] = data['Case Number.1'].str.replace('.', '/')
print(set(data['Case Number.1']))
# Out:
# {'2007/05/07/b', '1960/08/10', '2009/02/18', '2012/03/01', '1832/01/23/R', '2013/08/11', '1963/12/26/a', '1969/09/06', '2008/08/30/c', '2015/09/06', '2006/08/15', '1963/10/15', '1999/03/18/b', '1975/11/19/b', '1912/02/19', '1907/10/16/R', '1956/02/10/R', '1960/01/13', '2000/07/15/a', '1989/09/09/a', '1958/01/19', '1989/06/03', '1958/06/02/R', '1897/10/15', '1931/08/18', '1916/07/13/b', '1959/08/15/a', '1938/01/21', 'ND/0086', '1985/00/00/a', '1972/08/08', '2005/11/12', '1895/06/13/R', '1830/07/02/R', '2010/12/05', '1981/06/12', '1940/01/23', '1964/02/10', '2007/12/14', '1945/00/00/c', '1966/08/13', '2011/06/06/R', '1969/07/22', '1964/01/21', '1995/00/00/c', '1958/11/23', '1931/03/22', '2007/08/19/c', '1926/07/23', '2007/07/21', '1975/07/26/b', '1965/05/29', '1959/08/11', '1957/12/23', '1878/00/00', '1847/11/30', '2006/09/03/b', '1999/10/01', '1988/07/04/a', '1951/03/26', '1837/01/17', '1986/09/00/b', '1928/01/00', '2010/09/13', '1993/06/30', '2014/11/17', '2009/01/24/c', '1554/00/00'
# ...

# %%
data.head(3)
# Out:
#     Case Number       Date  Year        Type Country     Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked     USA  Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked     USA  Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked     USA  Florida
#
#                            Location Activity            Name Sex  Age  \
# 0  New Smyrna Beach, Volusia County  Surfing            male    M  16
# 1  New Smyrna Beach, Volusia County  Surfing  Chucky Luciano    M  36
# 2  New Smyrna Beach, Volusia County  Surfing            male    M  43
#
#                      Injury Fatal (Y/N)   Time Species   \
# 0     Minor injury to thigh           N  13h00      NaN
# 1      Lacerations to hands           N  11h00      NaN
# 2  Lacerations to lower leg           N  10h43      NaN
#
#         Investigator or Source                       pdf  \
# 0  Orlando Sentinel, 9/19/2016      2016.09.18.c-NSB.pdf
# 1  Orlando Sentinel, 9/19/2016  2016.09.18.b-Luciano.pdf
# ...
