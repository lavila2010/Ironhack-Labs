# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
from scipy import stats
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
data = pd.read_csv('C:/Users/leandro/desktop/ironhack/module-1/Dataframe-Calculations/data/Pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
type1_type2 =data[['Type 1', 'Type 2']].to_numpy()
#type1_2=set(type1_type2)
#type1_2
type(type1_type2)
# Out:
# numpy.ndarray

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here
def names (x):
    if 'Mega' in x:
        x = x.split()
        if len(x)>1:
            return 'Mega'+" "+x[1]
    else:
        return x
data['Name']=list(map(names,data['Name']))
# test transformed data

# %%
data.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
data['A/D Ratio']=''
data['A/D Ratio']= data['Attack']/data['Defense']

# %%
data.sort_values(by = 'A/D Ratio', ascending = False)
# Out:
#        #                Name   Type 1   Type 2  Total   HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic      NaN    600   50     180       20
# 347  318            Carvanha    Water     Dark    305   45      90       20
# 19    15       Mega Beedrill      Bug   Poison    495   65     150       40
# 453  408            Cranidos     Rock      NaN    350   67     125       40
# 348  319            Sharpedo    Water     Dark    460   70     120       40
# ..   ...                 ...      ...      ...    ...  ...     ...      ...
# 616  555  DarmanitanZen Mode     Fire  Psychic    540  105      30      105
# 103   95                Onix     Rock   Ground    385   35      45      160
# 484  436             Bronzor    Steel  Psychic    300   57      24       86
# 139  129            Magikarp    Water      NaN    200   20      10       55
# 230  213             Shuckle      Bug     Rock    505   20      10      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True   9.000000
# 347       65       20     65           3      False   4.500000
# 19        15       80    145           1      False   3.750000
# 453       30       30     58           4      False   3.125000
# 348       95       40     95           3      False   3.000000
# ..       ...      ...    ...         ...        ...        ...
# 616      140      105     55           5      False   0.285714
# 103       30       45     70           1      False   0.281250
# 484       24       86     23           4      False   0.279070
# 139       15       20     80           1      False   0.181818
# 230       10      230      5           2      False   0.043478
#
# [800 rows x 14 columns]

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
#data.groupby(['Name'])['A/D Ratio'].max()
data.loc[data['A/D Ratio'].idxmax('Name')]
# Out:
# #                            386
# Name          DeoxysAttack Forme
# Type 1                   Psychic
# Type 2                       NaN
# Total                        600
# HP                            50
# Attack                       180
# Defense                       20
# Sp. Atk                      180
# Sp. Def                       20
# Speed                        150
# Generation                     3
# Legendary                   True
# A/D Ratio                      9
# Name: 429, dtype: object

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
data.loc[data['A/D Ratio'].idxmin('Name')]
# Out:
# #                   213
# Name            Shuckle
# Type 1              Bug
# Type 2             Rock
# Total               505
# HP                   20
# Attack               10
# Defense             230
# Sp. Atk              10
# Sp. Def             230
# Speed                 5
# Generation            2
# Legendary         False
# A/D Ratio     0.0434783
# Name: 230, dtype: object

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here
data['Combo Type']=''

# %%
data.head(2)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary  A/D Ratio Combo Type
# 0     45           1      False   1.000000
# 1     60           1      False   0.984127

# %%
data['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
data['Type 2'].shape
# Out:
# (800,)

# %%
combo1=[]
for i in range(len(data["Type 2"])):
    if i == " nan":
        combo1.append(data["Type 1"][i])
    elif i != " nan":
        combo1.append(str(data["Type 1"][i]+"-"+str(data["Type 2"][i])))
    else: 
        print("nan not here")
print(len(combo1))
# Out:
# 800

# %%
data['Combo Type'] = combo1

# %%
data.head(50)
# Out:
#      #            Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    1       Bulbasaur     Grass  Poison    318   45      49       49
# 1    2         Ivysaur     Grass  Poison    405   60      62       63
# 2    3        Venusaur     Grass  Poison    525   80      82       83
# 3    3   Mega Venusaur     Grass  Poison    625   80     100      123
# 4    4      Charmander      Fire     NaN    309   39      52       43
# 5    5      Charmeleon      Fire     NaN    405   58      64       58
# 6    6       Charizard      Fire  Flying    534   78      84       78
# 7    6  Mega Charizard      Fire  Dragon    634   78     130      111
# 8    6  Mega Charizard      Fire  Flying    634   78     104       78
# 9    7        Squirtle     Water     NaN    314   44      48       65
# 10   8       Wartortle     Water     NaN    405   59      63       80
# 11   9       Blastoise     Water     NaN    530   79      83      100
# 12   9  Mega Blastoise     Water     NaN    630   79     103      120
# 13  10        Caterpie       Bug     NaN    195   45      30       35
# 14  11         Metapod       Bug     NaN    205   50      20       55
# 15  12      Butterfree       Bug  Flying    395   60      45       50
# 16  13          Weedle       Bug  Poison    195   40      35       30
# 17  14          Kakuna       Bug  Poison    205   45      25       50
# 18  15        Beedrill       Bug  Poison    395   65      90       40
# 19  15   Mega Beedrill       Bug  Poison    495   65     150       40
# 20  16          Pidgey    Normal  Flying    251   40      45       40
# 21  17       Pidgeotto    Normal  Flying    349   63      60       55
# 22  18         Pidgeot    Normal  Flying    479   83      80       75
# 23  18    Mega Pidgeot    Normal  Flying    579   83      80       80
# 24  19         Rattata    Normal     NaN    253   30      56       35
# 25  20        Raticate    Normal     NaN    413   55      81       60
# 26  21         Spearow    Normal  Flying    262   40      60       30
# 27  22          Fearow    Normal  Flying    442   65      90       65
# 28  23           Ekans    Poison     NaN    288   35      60       44
# 29  24           Arbok    Poison     NaN    438   60      85       69
# 30  25         Pikachu  Electric     NaN    320   35      55       40
# 31  26          Raichu  Electric     NaN    485   60      90       55
# 32  27       Sandshrew    Ground     NaN    300   50      75       85
# 33  28       Sandslash    Ground     NaN    450   75     100      110
# 34  29        Nidoran♀    Poison     NaN    275   55      47       52
# 35  30        Nidorina    Poison     NaN    365   70      62       67
# 36  31       Nidoqueen    Poison  Ground    505   90      92       87
# 37  32        Nidoran♂    Poison     NaN    273   46      57       40
# 38  33        Nidorino    Poison     NaN    365   61      72       57
# 39  34        Nidoking    Poison  Ground    505   81     102       77
# 40  35        Clefairy     Fairy     NaN    323   70      45       48
# 41  36        Clefable     Fairy     NaN    483   95      70       73
# 42  37          Vulpix      Fire     NaN    299   38      41       40
# 43  38       Ninetales      Fire     NaN    505   73      76       75
# 44  39      Jigglypuff    Normal   Fairy    270  115      45       20
# 45  40      Wigglytuff    Normal   Fairy    435  140      70       45
# 46  41           Zubat    Poison  Flying    245   40      45       35
# 47  42          Golbat    Poison  Flying    455   75      80       70
# 48  43          Oddish     Grass  Poison    320   45      50       55
# 49  44           Gloom     Grass  Poison    395   60      65       70
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 0        65       65     45           1      False   1.000000   Grass-Poison
# 1        80       80     60           1      False   0.984127   Grass-Poison
# 2       100      100     80           1      False   0.987952   Grass-Poison
# 3       122      120     80           1      False   0.813008   Grass-Poison
# 4        60       50     65           1      False   1.209302       Fire-nan
# 5        80       65     80           1      False   1.103448       Fire-nan
# 6       109       85    100           1      False   1.076923    Fire-Flying
# 7       130       85    100           1      False   1.171171    Fire-Dragon
# 8       159      115    100           1      False   1.333333    Fire-Flying
# 9        50       64     43           1      False   0.738462      Water-nan
# 10       65       80     58           1      False   0.787500      Water-nan
# 11       85      105     78           1      False   0.830000      Water-nan
# 12      135      115     78           1      False   0.858333      Water-nan
# 13       20       20     45           1      False   0.857143        Bug-nan
# 14       25       25     30           1      False   0.363636        Bug-nan
# 15       90       80     70           1      False   0.900000     Bug-Flying
# 16       20       20     50           1      False   1.166667     Bug-Poison
# 17       25       25     35           1      False   0.500000     Bug-Poison
# 18       45       80     75           1      False   2.250000     Bug-Poison
# 19       15       80    145           1      False   3.750000     Bug-Poison
# 20       35       35     56           1      False   1.125000  Normal-Flying
# 21       50       50     71           1      False   1.090909  Normal-Flying
# 22       70       70    101           1      False   1.066667  Normal-Flying
# 23      135       80    121           1      False   1.000000  Normal-Flying
# 24       25       35     72           1      False   1.600000     Normal-nan
# 25       50       70     97           1      False   1.350000     Normal-nan
# 26       31       31     70           1      False   2.000000  Normal-Flying
# 27       61       61    100           1      False   1.384615  Normal-Flying
# 28       40       54     55           1      False   1.363636     Poison-nan
# 29       65       79     80           1      False   1.231884     Poison-nan
# 30       50       50     90           1      False   1.375000   Electric-nan
# 31       90       80    110           1      False   1.636364   Electric-nan
# 32       20       30     40           1      False   0.882353     Ground-nan
# 33       45       55     65           1      False   0.909091     Ground-nan
# 34       40       40     41           1      False   0.903846     Poison-nan
# 35       55       55     56           1      False   0.925373     Poison-nan
# 36       75       85     76           1      False   1.057471  Poison-Ground
# 37       40       40     50           1      False   1.425000     Poison-nan
# 38       55       55     65           1      False   1.263158     Poison-nan
# 39       85       75     85           1      False   1.324675  Poison-Ground
# 40       60       65     35           1      False   0.937500      Fairy-nan
# 41       95       90     60           1      False   0.958904      Fairy-nan
# 42       50       65     65           1      False   1.025000       Fire-nan
# 43       81      100    100           1      False   1.013333       Fire-nan
# 44       45       25     20           1      False   2.250000   Normal-Fairy
# 45       85       50     45           1      False   1.555556   Normal-Fairy
# 46       30       40     55           1      False   1.285714  Poison-Flying
# 47       65       75     90           1      False   1.142857  Poison-Flying
# 48       75       65     30           1      False   0.909091   Grass-Poison
# 49       85       75     40           1      False   0.928571   Grass-Poison

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here
five_top=data.nlargest(5, ['A/D Ratio']) 
five_top
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio   Combo Type
# 429      180       20    150           3       True      9.000  Psychic-nan
# 347       65       20     65           3      False      4.500   Water-Dark
# 19        15       80    145           1      False      3.750   Bug-Poison
# 453       30       30     58           4      False      3.125     Rock-nan
# 348       95       40     95           3      False      3.000   Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
top5df =pd.DataFrame(data.nlargest(5, ['A/D Ratio']))
top5df
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio   Combo Type
# 429      180       20    150           3       True      9.000  Psychic-nan
# 347       65       20     65           3      False      4.500   Water-Dark
# 19        15       80    145           1      False      3.750   Bug-Poison
# 453       30       30     58           4      False      3.125     Rock-nan
# 348       95       40     95           3      False      3.000   Water-Dark

# %%
top_5_Combo_Type= top5df["Combo Type"].to_numpy()
print(top_5_Combo_Type)
# Out:
# ['Psychic-nan' 'Water-Dark' 'Bug-Poison' 'Rock-nan' 'Water-Dark']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
#data.columns
