# %%
import pandas as pd

# %%
with open('C:/Users/leandro/Desktop/igprofiles.json','r', encoding='utf8') as f:
    x = f.readlines()

# %%
data = pd.read_json('C:/Users/leandro/Desktop/igprofiles.json', lines=True)

# %%
data.head(20)
# Out:
#                                      _id          id                  __v  \
# 0   {'$oid': '5e7021f58ddab2091717b8b5'}    24686696  {'$numberInt': '0'}
# 1   {'$oid': '5e7021f58ddab2091717b8b8'}     3532778  {'$numberInt': '0'}
# 2   {'$oid': '5e7021f58ddab2091717b8b6'}    12935380  {'$numberInt': '0'}
# 3   {'$oid': '5e7021f58ddab2091717b8c1'}     3956455  {'$numberInt': '0'}
# 4   {'$oid': '5e7021f58ddab2091717b8d6'}   245985864  {'$numberInt': '0'}
# 5   {'$oid': '5e7021f58ddab2091717b8f0'}      582820  {'$numberInt': '0'}
# 6   {'$oid': '5e7021f58ddab2091717b90a'}    42100040  {'$numberInt': '0'}
# 7   {'$oid': '5e7021f58ddab2091717b925'}   270612568  {'$numberInt': '0'}
# 8   {'$oid': '5e7021f58ddab2091717b93d'}   321904988  {'$numberInt': '0'}
# 9   {'$oid': '5e7021f58ddab2091717b956'}    31338835  {'$numberInt': '0'}
# 10  {'$oid': '5e7021f58ddab2091717b96f'}    18883735  {'$numberInt': '0'}
# 11  {'$oid': '5e7021f58ddab2091717b98e'}     8771119  {'$numberInt': '0'}
# 12  {'$oid': '5e7021f58ddab2091717b9a5'}    22568518  {'$numberInt': '0'}
# 13  {'$oid': '5e7021f68ddab2091717b9c1'}    12217636  {'$numberInt': '0'}
# 14  {'$oid': '5e7021f68ddab2091717b9d9'}     3594350  {'$numberInt': '0'}
# 15  {'$oid': '5e7021f68ddab2091717b9f5'}  2113357247  {'$numberInt': '0'}
# 16  {'$oid': '5e7021f68ddab2091717ba0e'}   526770139  {'$numberInt': '0'}
# 17  {'$oid': '5e7021f68ddab2091717ba27'}    37892027  {'$numberInt': '0'}
# 18  {'$oid': '5e7021f68ddab2091717ba41'}    27912457  {'$numberInt': '0'}
# 19  {'$oid': '5e702da78ddab2091717c1c7'}     4701997  {'$numberInt': '0'}
#
#                                             biography  blocked_by_viewer  \
# 0   Contact: mail@ladyironchef.com\nFacebook.com/l...              False
# 1   Chef & Dad\nRecipe links, book links & more ri...              False
# 2   Best-selling cookbook author + former fast-foo...              False
# 3   Life and stuff. // Check out our award winning...              False
# 4   ðŸ�€ ðŸ�‘ & ðŸ‘¶ðŸ�» ðŸ‘‘ sr.\npodcast: @davec...              False
# 5   I'm Ida Skivenes from Norway. All the food art...              False
# 6   Wife | Mama | Author | Food Photographer | Blo...              False
# 7   Yolks and dad jokes.\nSAVEUR Blog Awards Winne...              False
# 8   photographer + NYC stan + caesar salad enthusi...              False
# 9   Food blogger and NYT bestselling author. I foc...              False
# 10  + Chef \n+ Cookbook Author  (Eat Delicious)\n+...              False
# 11  Photography | Vancouver, Canada | Studio @domi...              False
# 12  sweetness, flowering. \ndÃ©but cookbook with @...              False
# 13  ðŸ’• marzipan, sprinkles, tahini \nðŸ‘©ðŸ�»â€�...              False
# 14  +65 | 28yrs\nï¼ŽProfessional photographer\nï¼Ž...              False
# 15  ðŸŒ± #Vegan Recipe Creator and Chef\nðŸŒ± Vega...              False
# 16  #glutenfree ðŸ‘‘ \nwellness, fitness, music, m...              False
# 17  simple recipes that make you feel good â€¢ 10 ...              False
# 18  Mama of two + Lover of chocolate + Drinker of ...              False
# 19  Tools + Inspiration to Live Your Bucket List. ...              False
#
#                          business_category_name   category_id  \
# 0                                          None  1.602000e+03
# 1                         Food & Personal Goods  1.562965e+15
# 2                                          None           NaN
# 3                                          None  1.109000e+03
# 4                                  Local Events           NaN
# 5                             Home Goods Stores  1.328526e+14
# 6                                          None  3.612820e+14
# 7                                          None           NaN
# 8                                          None  1.814756e+14
# 9                                          None  1.301000e+03
# 10                       Creators & Celebrities  1.606000e+03
# 11                                         None  1.814756e+14
# 12                                         None           NaN
# 13                       Creators & Celebrities  2.700000e+03
# 14                                         None  1.601000e+03
# 15                                         None  3.612820e+14
# 16  Personal Goods & General Merchandise Stores  2.202000e+03
# 17                                   Publishers  2.707000e+03
# 18                                         None           NaN
# 19                                         None  1.602000e+03
#
#     connected_fb_page  country_block  \
# 0                 NaN          False
# 1                 NaN          False
# 2                 NaN          False
# 3                 NaN          False
# 4                 NaN          False
# 5                 NaN          False
# 6                 NaN          False
# 7                 NaN          False
# 8                 NaN          False
# 9                 NaN          False
# 10                NaN          False
# 11                NaN          False
# 12                NaN          False
# 13                NaN          False
# 14                NaN          False
# 15                NaN          False
# 16                NaN          False
# 17                NaN          False
# 18                NaN          False
# 19                NaN          False
#
#                             edge_felix_video_timeline  ... is_joined_recently  \
# 0   {'count': {'$numberInt': '207'}, 'page_info': ...  ...              False
# 1   {'count': {'$numberInt': '137'}, 'page_info': ...  ...              False
# 2   {'count': {'$numberInt': '25'}, 'page_info': {...  ...              False
# 3   {'count': {'$numberInt': '1'}, 'page_info': {'...  ...              False
# 4   {'count': {'$numberInt': '9'}, 'page_info': {'...  ...              False
# 5   {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 6   {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 7   {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 8   {'count': {'$numberInt': '2'}, 'page_info': {'...  ...              False
# 9   {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 10  {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 11  {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 12  {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 13  {'count': {'$numberInt': '2'}, 'page_info': {'...  ...              False
# 14  {'count': {'$numberInt': '2'}, 'page_info': {'...  ...              False
# 15  {'count': {'$numberInt': '16'}, 'page_info': {...  ...              False
# 16  {'count': {'$numberInt': '5'}, 'page_info': {'...  ...              False
# 17  {'count': {'$numberInt': '2'}, 'page_info': {'...  ...              False
# 18  {'count': {'$numberInt': '0'}, 'page_info': {'...  ...              False
# 19  {'count': {'$numberInt': '1'}, 'page_info': {'...  ...              False
#
#    is_private is_verified overall_category_name  \
# 0       False        True                   NaN
# 1       False        True                   NaN
# 2       False        True                   NaN
# 3       False       False                   NaN
# 4       False        True                   NaN
# 5       False       False                   NaN
# 6       False       False                   NaN
# 7       False       False                   NaN
# 8       False       False                   NaN
# 9       False       False                   NaN
# 10      False        True                   NaN
# 11      False       False                   NaN
# 12      False        True                   NaN
# 13      False        True                   NaN
# 14      False       False                   NaN
# 15      False       False                   NaN
# 16      False        True                   NaN
# 17      False        True                   NaN
# 18       True       False                   NaN
# 19      False        True                   NaN
#
#                                       profile_pic_url  \
# 0   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 1   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 2   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 3   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 4   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 5   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 6   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 7   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 8   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 9   https://scontent-mia3-1.cdninstagram.com/v/t51...
# 10  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 11  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 12  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 13  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 14  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 15  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 16  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 17  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 18  https://scontent-mia3-1.cdninstagram.com/v/t51...
# 19  https://scontent-frt3-1.cdninstagram.com/v/t51...
#
#                                    profile_pic_url_hd requested_by_viewer  \
# 0   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 1   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 2   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 3   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 4   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 5   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 6   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 7   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 8   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 9   https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 10  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 11  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 12  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 13  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 14  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 15  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 16  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 17  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 18  https://scontent-mia3-1.cdninstagram.com/v/t51...               False
# 19  https://scontent-frt3-1.cdninstagram.com/v/t51...               False
#
#    restricted_by_viewer           username  elmcategory
# 0                   NaN       ladyironchef         food
# 1                   NaN        jamieoliver         food
# 2                   NaN        detoxinista         food
# 3                   NaN             ashrod         food
# 4                   NaN         davidchang         food
# 5                   NaN           idafrosk         food
# 6                   NaN    dollyandoatmeal         food
# 7                   NaN          dad_beets         food
# 8                   NaN     mollytavoletti         food
# 9                   NaN     thedomesticman         food
# 10                  NaN  dennistheprescott         food
# 11                  NaN    artfuldesperado         food
# 12                  NaN           thaliaho         food
# 13                  NaN           mollyyeh         food
# 14                  NaN              xlbcr         food
# 15                  NaN           elavegan         food
# 16                  NaN            nobread         food
# 17                  NaN    minimalistbaker         food
# 18                  NaN         yumnajawad         food
# 19                  NaN  bucketlistjourney       travel
#
# [20 rows x 37 columns]
