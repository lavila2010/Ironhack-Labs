# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import urllib.request

# %%
from bs4 import BeautifulSoup
url='https://www.outsideonline.com/2128816/definitive-superfood-ranking'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en" xmlns:fb="https://ogp.me/ns/fb#">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script id="page-ad-vars">window.outside_gpt = {"zone" : "/299403/outside.health/nutrition", "sec" : "", "page" : "the-definitive-superfood-ranking", "hierarchy" : "/health/nutrition/the-definitive-superfood-ranking/", "author" : "AC Shilton", "companion" : false, "preroll" : true, "disable_ads" : false, "env" : window.location.host === "www.outsideonline.com" ? "live" : (window.location.host === "test-outside1.pantheonsite.io" ? "test" : "dev"), "cat" : ["food-and-drink","science"], "terms" : ["Health","Nutrition"], "content_type" : "article_infinite_stack", "created" : "2016-10-31T01:00:00-05:00", "content_issue" : "Outside Online", "affiliate_native" : "not_applicable"};
# if (typeof window.newrelic == "object") {newrelic.setCustomAttribute("contentType", "article_infinite_stack");newrelic.setCustomAttribute("hierarchy", "/health/nutrition/the-definitive-superfood-ranking/");}</script> <script>window.amplitude_content_type="article";window.amplitude_page_data={"author":"AC Shilton","category":["Food and Drink","Science"],"magazine issue":"Outside Online","contains affiliate":false,"is native":false,"word count":2397,"average read time minutes":11,"average read time seconds":639,"character count":15107,"is stack":true,"page title":"The Definitive Superfood Ranking","page nid":"2128816","publish date":"2016-10-31","content type":"article","placement":["Nutrition","Health"],"channel name":"Health","url":"\/2128816\/definitive-superfood-ranking","api_key":"d14e9390e0d6d31e46c5b5b09539ad0d"}</script> <link href="https://connect.facebook.net" rel="dns-prefetch"/>
# <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net" rel="preconnect"/>
# <link href="https://pixel.quantserve.com" rel="dns-prefetch"/>
# <link href="https://pixel.quantserve.com" rel="preconnect"/>
# <link href="https://mab.chartbeat.com" rel="preconnect"/>
# <link href="https://cdn.amplitude.com" rel="preconnect"/>
# <link href="https://cdn.amplitude.com" rel="dns-prefetch"/>
# <link href="https://secure.quantserve.com" rel="preconnect"/>
# <link href="https://secure.quantserve.com" rel="dns-prefetch"/>
# <link href="https://mab.chartbeat.com" rel="dns-prefetch"/>
# <link href="https://www.googletagservices.com" rel="preconnect"/>
# <link href="https://www.googletagservices.com" rel="dns-prefetch"/>
# <link href="https://rules.quantcount.com" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://adservice.google.com" rel="dns-prefetch"/>
# <link href="https://adservice.google.com" rel="preconnect"/>
# <link href="https://www.facebook.com" rel="dns-prefetch"/>
# <link href="https://www.facebook.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://t1.createsend1.com" rel="dns-prefetch"/>
# <link href="https://t1.createsend1.com" rel="preconnect"/>
# <link href="https://cdn.parsely.com/" rel="dns-prefetch"/>
# <link href="https://cdn.parsely.com/" rel="preconnect"/>
# <meta content="width=device-width, initial-scale=1, height=device-height" name="viewport"/>
# <link href="https://www.google.com" rel="dns-prefetch"/>
# <link href="https://www.google.com" rel="preconnect"/>
# <link href="https://rules.quantcount.com" rel="dns-prefetch"/>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Article","url":"https://www.outsideonline.com/2128816/definitive-superfood-ranking","articleSection":"Health - Nutrition","keywords":["category: Food and Drink","category: Science","type: Stack Article"],"mainEntityOfPage":{"@type":"WebPage","@id":"/2128816/definitive-superfood-ranking"},"headline":"The Definitive Superfood Ranking","name":"The Definitive Superfood Ranking","image":{"@type":"ImageObject","url":"https://www.outsideonline.com/sites/default/files/styles/img_850x480/public/2016/10/24/superfood-matrix_h.jpg?itok=L8TG-uUI","width":850,"height":480},"thumbnailUrl":"https://www.outsideonline.com/sites/default/files/styles/img_850x480/public/2016/10/24/superfood-matrix_h.jpg?itok=L8TG-uUI","datePublished":"2016-10-31T01:00:00-05:00","dateModified":"2019-07-24T16:33:33-05:00","author":[{"@type":"Person","name":"AC Shilton"}],"description":"It seems like everything these days is considered a superfood, so we decided to look into which of these foods are actually research-backed and which ones are all hype.","publisher":{"@type":"Organization","name":"Outside Magazine","logo":{"@type":"ImageObject","url":"https://www.outsideonline.com/sites/all/themes/outside/images/outside-logo.png","width":165,"height":50}}}</script>
# <link href="/sites/default/files/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/sites/default/files/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/sites/default/files/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
# <link href="/sites/default/files/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/sites/default/files/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/sites/default/files/favicons/site.webmanifest" rel="manifest"/>
# <link color="#ffd204" href="/sites/default/files/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="AC Shilton" name="parsely-author"/>
# <meta content="https://www.outsideonline.com/2128816/definitive-superfood-ranking" name="parsely-link"/>
# <meta content="post" name="parsely-type"/>
# <meta content="Health - Nutrition" name="parsely-section"/>
# <meta content="category: Food and Drink,category: Science,type: Stack Article" name="parsely-tags"/>
# <meta content="The Definitive Superfood Ranking" name="parsely-title"/>
# <meta content="https://www.outsideonline.com/sites/default/files/styles/img_850x480/public/2016/10/24/superfood-matrix_h.jpg?itok=L8TG-uUI" name="parsely-image-url"/>
# <link href="https://js.createsend.events" rel="preconnect"/>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Nutrition","item":"https://www.outsideonline.com/health/nutrition"},{"@type":"ListItem","position":2,"name":"Health","item":"https://www.outsideonline.com/health"}]}</script>
# <meta content="2016-10-31T01:00:00-05:00" name="parsely-pub-date"/>
# <link href="https://js.createsend.events" rel="dns-prefetch"/>
# <meta content="It seems like everything these days is considered a superfood, so we decided to look into which of these foods are actually research-backed and which ones are all hype." name="description"/>
# <link href="https://www.outsideonline.com/2128816/definitive-superfood-ranking" rel="canonical"/>
# <link href="https://www.outsideonline.com/node/2128816" rel="shortlink"/>
# <meta content="857719864360820" property="fb:app_id"/>
# <meta content="Outside Online" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="The Definitive Superfood Ranking" property="og:title"/>
# <meta content="https://www.outsideonline.com/2128816/definitive-superfood-ranking" property="og:url"/>
# <meta content="AC Shilton" name="author"/>
# <meta content='It seems like everything in the grocery store is labeled "super." We dove into which foods are actually proven, by science, to be good for you and which ones are all hype.' property="og:description"/>
# <meta content="2019-07-24T16:33:33-05:00" property="og:updated_time"/>
# <meta content="https://www.outsideonline.com/sites/default/files/styles/full-page/public/2016/10/24/superfood-matrix_h.jpg?itok=tgVJBNXT" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="675" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://www.outsideonline.com/2128816/definitive-superfood-ranking" name="twitter:url"/>
# <meta content="The Definitive Superfood Ranking" name="twitter:title"/>
# <meta content="It seems like everything these days is considered a superfood, so we decided to look into which of these foods are actually research-backed and which ones are all hype." name="twitter:description"/>
# <meta content="https://www.outsideonline.com/sites/default/files/styles/full-page/public/2016/10/24/superfood-matrix_h.jpg?itok=tgVJBNXT" name="twitter:image"/>
# <meta content="@outsidemagazine" name="twitter:site"/>
# <meta content="" name="twitter:player"/>
# <meta content="850" name="twitter:player:width"/>
# <meta content="480" name="twitter:player:height"/>
# <meta content="2016-10-31T01:00:00-05:00" property="article:published_time"/>
# <meta content="2019-07-24T16:33:33-05:00" property="article:modified_time"/>
# <title>The Definitive Superfood Ranking | Outside Online</title>
# <meta content="mu-dde8cda0-5437cf21-c3ea2762-6d95903c" name="blitz"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://www.outsideonline.com/sites/default/files/css/css_CxMORm1rvbUqJcNz1i4OaHmxJu8jeyIrceglLXJczHM.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.outsideonline.com/sites/default/files/css/css_V4_l7gIbCLAmFRhpp4KdpQZst-kNY2KGQWJZyoxbYhA.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.outsideonline.com/sites/default/files/css/css_47DEQpj8HBSa-_TImW-5JCeuQeRkm5NMpJWZG3hSuFU.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# document.querySelector("html").classList.add("js"); var Drupal = {}; Drupal.settings = {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"outside","theme_token":"E7EOQVEqRasUqfGsD3jexb-6t1kmMt6c1EzSwPJwZp4","jquery_version":"3.1","js":{"sites\/all\/modules\/custom\/outside_article\/js\/dist\/articles.min.js":1},"css":{"sites\/all\/modules\/contrib\/youtube\/css\/youtube.css":1,"sites\/all\/themes\/outside\/css\/page-types\/article.css":1,"sites\/all\/themes\/outside\/defaults.css":1,"sites\/all\/themes\/outside\/system-menus.css":1,"sites\/all\/themes\/outside\/system.css":1,"sites\/all\/themes\/outside\/node.css":1,"sites\/all\/themes\/outside\/search.css":1,"sites\/all\/themes\/outside\/user.css":1,"sites\/all\/themes\/outside\/apachesolr_autocomplete.css":1,"sites\/all\/themes\/outside\/jquery.autocomplete.css":1,"sites\/all\/themes\/outside\/content-module.css":1,"sites\/all\/themes\/outside\/date.css":1,"sites\/all\/themes\/outside\/datepicker.1.7.css":1,"sites\/all\/themes\/outside\/jquery.timeentry.css":1,"sites\/all\/themes\/outside\/filefield.css":1,"sites\/all\/themes\/outside\/fieldgroup.css":1,"sites\/all\/themes\/outside\/content_multigroup.css":1,"sites\/all\/themes\/outside\/printlinks.css":1,"sites\/all\/themes\/outside\/ctools.css":1,"sites\/all\/themes\/outside\/views.css":1,"sites\/all\/themes\/outside\/field.css":1,"sites\/all\/themes\/outside\/jquery.ui.tabs.css":1,"sites\/all\/themes\/outside\/datepicker.css":1,"sites\/all\/themes\/outside\/ui.datepicker.css":1,"sites\/all\/themes\/outside\/ui.all.css":1,"sites\/all\/themes\/outside\/panels.css":1}},"ajax":{"edit-submit":{"callback":"outside_newsletter_inline_signup_form_callback","wrapper":"outside-newsletter-inline-signup-form","method":"replaceWith","effect":"fade","progress":{"type":"none","message":null},"event":"mousedown","keypress":true,"prevent":"click","url":"\/system\/ajax","submit":{"_triggering_element_name":"op","_triggering_element_value":"Get It"}}},"urlIsAjaxTrusted":{"\/system\/ajax":true,"\/2128816\/definitive-superfood-ranking":true},"password":{"strengthTitle":"Password compliance:"},"type":"setting"}
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# // Check window width
# var getWidth = function() {
#   var width;
#   if (document.body && document.body.offsetWidth) {
#     width = document.body.offsetWidth;
#   }
#   if (document.compatMode === 'CSS1Compat' &&
#     document.documentElement &&
#     document.documentElement.offsetWidth ) {
#     width = document.documentElement.offsetWidth;
#   }
#   if (window.innerWidth) {
#     width = window.innerWidth;
#   }
#   return width;
# };
# // global breakpoints
# var px500 = 500,
#     px750 = 750,
#     px800 = 800,
#     breakIntoColumns = 900,
#     px1000 = 1000,
#     pxmax = 1320;
# //--><!]]>
# </script>
# </head>
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-2128816 node-type-article node-type-linear-article site-bg--gray js-page--infinite-stack role-anonymous-user">
# <script>
# /* ADVAGG INLINE SKIP BLOCK */
# !function(e){var t={};function n(r){if(t[r])return t[r].exports;var o=t[r]={i:r,l:!1,exports:{}};return e[r].call(o.exports,o,o.exports,n),o.l=!0,o.exports}n.m=e,n.c=t,n.d=function(e,t,r){n.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},n.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},n.t=function(e,t){if(1&t&&(e=n(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var r=Object.create(null);if(n.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var o in e)n.d(r,o,function(t){return e[t]}.bind(null,o));return r},n.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return n.d(t,"a",t),t},n.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},n.p="/sites/all/modules/custom/outside_js/js/dist/",n(n.s=0)}([function(e,t,n){"use strict";n.r(t);var r=window.location.search,o=new URLSearchParams(r);function a(){performance.mark("mark_time_to_user_action"),document.body.removeEventListener("click",a),window.removeEventListener("scroll",a)}!o.has("siteshare")||o.has("utm_medium")||o.has("utm_source")||o.has("utm_campaign")||history.replaceState({},document.title,window.location.href+"&utm_medium=social&utm_source="+o.get("siteshare")+"&utm_campaign=onsiteshare"),document.body.dataset.jsToggleParent||function(e,t,n,r){if(!t||!e||!n||"function"!=typeof r)return null;t.forEach((function(t){e.addEventListener(t,(function(e){var t=e.target||null,o=[t];if(!t||!t.parentElement)return[];for(;t.parentElement;)t=t.parentElement,o.unshift(t);o.filter((function(e){return e.matches(n)})).forEach((function(t){r.apply(t,[e])}))}))}))}(document.body,["click"],".js-toggle-parent",(function(e){document.body.dataset.jsToggleParent="true",this.parentElement.classList.toggle("is-active"),e.preventDefault()})),document.body.dataset.jsToggleParent=!0,document.body.addEventListener("click",a),window.addEventListener("scroll",a),window.addEventListener("DOMContentLoaded",(function(){performance.mark("mark_fully_visible")}),!0),window.addEventListener("load",(function(){performance.mark("mark_fully_loaded")}))}]);
# </script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K4NWW8" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>console.log(window.location.search);(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-K4NWW8');</script>
# <div class="main-container">
# <header class="site-header" role="banner">
# <div class="site-header__inner js-site-header">
# <div class="site-header__logo">
# <a class="site-header__logo-link no-hover" data-amplitude-internal-source="top logo" data-ga-event-action="mainNav" data-ga-event-category="logo" data-ga-event-label="/" data-ga-event-on="click" href="/"><svg viewbox="0 0 424.75 108.37" xmlns="http://www.w3.org/2000/svg"><title>Outside</title><path d="M50.7,108.37c28.1,0,46.8-20.42,49-47.88h4.76V90.54c0,12,8.32,16.64,19.23,16.64A23.2,23.2,0,0,0,143.43,95.4v10.92h26V92.38h-8V60.49h12.75V85.13c0,14.7,5.84,22.05,19.34,22.05,7.79,0,12-3.78,15-8.11v7.25h12.11V98.43c6.26,6.7,12.42,8.75,21.61,8.75,8.44,0,15.35-2.92,19-8.32v7.46h39.46v-9c4.11,6.15,11.35,9.72,20.74,9.72,8.43,0,13.84-3.57,18.06-10v9.3H367.9V97.13c5.63,7.45,13.94,10.48,25.08,10.48,15.35,0,29.6-6.27,31.77-23.56H406.92c-1.41,7.46-4.87,11-12.75,11-6.61,0-11.25-4-11.58-15.46h41.62V77.13c0-19.45-11.57-31.66-30-31.66C377,45.47,363,57.36,363,76.49c0,5.94.86,11.45,2.91,15.77h-8.2V26.12H328.89V40.39h10.7V55a18.71,18.71,0,0,0-15.9-8.53C306,46.45,296.47,59,296.47,76.06a48.65,48.65,0,0,0,2.58,16.32h-9.61V46.45H247.29V53.9c-3.36-4.75-8.21-8-16.64-8-10.16,0-16.65,3.14-19.78,7.35v-7H192.71V30.45H178.34c0,10.7-2.81,15.78-17,15.78H133.49V60.81h9.83v18.7c0,7.46-3.78,13.19-11.89,13.19-6.91,0-8.75-4.65-8.75-10.8V46.23H98.8C94.47,22.88,77.72,3.75,50.7,3.75,19.58,3.75,1.64,26.56,1.64,56.6c0,29.18,19.56,51.77,49.06,51.77M238.64,95.73c-8.53,0-12.43-3.9-16.43-10.38H201.79c.32,6.6.22,10.27-4.22,10.27s-4.86-4.43-4.86-8V60.49h16.43a25.82,25.82,0,0,0-.11,2.92c0,27.34,37.5,16.32,37.5,27.56,0,3.89-4.54,4.75-7.88,4.75m24.63-3.46a28.69,28.69,0,0,0,.33-4.53c0-26.05-37.94-15.46-37.94-26.16,0-3.57,4.66-4.21,8.87-4.21,5.94,0,9.4,1.83,12.1,7.45h15.57V60.49h10.7V92.26ZM53.41,92.7c-14.7.1-23.68-23.34-23.68-44,0-11.89,4.54-29.94,18.05-29.94,18,0,23.89,29,23.89,43,0,13.3-4.32,30.91-18.26,30.91m274.72.54c-9.84,0-12-9.84-12-17.83,0-7.79,3-16.32,12.32-16.32,7.35,0,11.14,7,11.14,14v6c0,6.91-3.56,14.15-11.46,14.15M382.92,70c1.3-8.76,5.83-12.11,11.35-12.11,7.46,0,10.17,4.43,10.7,12.11ZM272.36,41.79h17.08V26.12H272.36Z" fill="#ed0505"></path><path d="M49.31,104.87c28.1,0,46.8-20.43,49-47.88H103V87c0,12,8.32,16.64,19.23,16.64A23.23,23.23,0,0,0,142.05,91.9v10.92h26V88.88h-8V57h12.75V81.63c0,14.7,5.84,22.05,19.35,22.05,7.78,0,12-3.78,15-8.11v7.25h12.11V94.93c6.27,6.7,12.43,8.75,21.61,8.75,8.44,0,15.35-2.92,19-8.32v7.46H299.4v-9c4.11,6.15,11.35,9.72,20.75,9.72,8.43,0,13.84-3.57,18.05-10v9.3h28.31V93.63c5.63,7.45,13.95,10.48,25.08,10.48,15.35,0,29.61-6.27,31.77-23.56H405.53c-1.41,7.46-4.86,11-12.75,11-6.6,0-11.24-4-11.57-15.46h41.61V73.63c0-19.45-11.57-31.66-30.05-31.66-17.18,0-31.12,11.89-31.12,31,0,5.94.86,11.45,2.92,15.77h-8.21V22.62H327.5V36.89h10.7V51.48A18.69,18.69,0,0,0,322.31,43c-17.72,0-27.23,12.53-27.23,29.61a49,49,0,0,0,2.58,16.32h-9.61V42.94H245.9V50.4c-3.36-4.75-8.21-8-16.64-8-10.16,0-16.65,3.14-19.78,7.35v-7H191.32V27H177c0,10.7-2.81,15.78-17,15.78H132.1V57.31h9.83V76c0,7.46-3.77,13.18-11.88,13.18-6.92,0-8.75-4.64-8.75-10.8V42.73H97.41C93.08,19.38,76.33.25,49.31.25,18.19.25.25,23.06.25,53.1c0,29.18,19.56,51.77,49.06,51.77m188-12.64c-8.53,0-12.43-3.9-16.44-10.38H200.4c.33,6.6.22,10.27-4.22,10.27s-4.86-4.43-4.86-8V57h16.43a28.39,28.39,0,0,0-.11,2.92c0,27.34,37.5,16.32,37.5,27.56,0,3.89-4.53,4.75-7.88,4.75m24.64-3.46a30,30,0,0,0,.32-4.54c0-26-37.94-15.45-37.94-26.15,0-3.57,4.66-4.21,8.87-4.21,5.94,0,9.4,1.83,12.1,7.45h15.57V57h10.7V88.76ZM52,89.2c-14.7.1-23.67-23.34-23.67-44,0-11.89,4.53-29.94,18-29.94,17.94,0,23.88,29,23.88,43C70.28,71.59,66,89.2,52,89.2m274.72.54c-9.84,0-12-9.84-12-17.83,0-7.79,3-16.32,12.33-16.32,7.34,0,11.13,7,11.13,14v6c0,6.91-3.56,14.15-11.46,14.15m54.8-23.23c1.29-8.76,5.83-12.11,11.35-12.11,7.45,0,10.16,4.43,10.7,12.11ZM271,38.29h17.08V22.62H271Z" fill="#ffd204" stroke="#454545" stroke-width="0.5"></path></svg>
# </a>
# </div>
# <div class="site-header__other no-print">
# <div class="site-header__icons">
# <a class="site-header__subscribe-text js-toggle" data-ga-custom-event-right-menu-toggle="" data-toggled="c-subscribe-dialog" href="https://subscribe.outsideonline.com/servlet/ConvertibleGateway?cds_mag_code=OUM&amp;cds_page_id=247857" rel="noopener" target="_blank">Subscribe</a>
# <div class="c-subscribe-dialog">
# <div class="c-subscribe-dialog__inner">
# <button class="close js-toggle" data-toggled="c-subscribe-dialog"><span class="is-vishidden">Close Subscribe</span></button>
# <div class="c-subscribe-dialog__links">
# <a class="c-subscribe-dialog__link" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/2063191\/newsletter-signup","title clicked to":"Newsletters"}' data-ga-event-action="mainNavRight" data-ga-event-category="newsletters" data-ga-event-label="/2063191/newsletter-signup" data-ga-event-on="click" href="/2063191/newsletter-signup" rel="noopener" target="_blank">
# Newsletters</a>
# <a class="c-subscribe-dialog__link" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"&lt;?php print $magazine_subscribe_link; ?&gt;","title clicked to":"Magazine"}' data-ga-event-action="mainNavRight" data-ga-event-category="magazine" data-ga-event-label="https://subscribe.outsideonline.com/servlet/ConvertibleGateway?cds_mag_code=OUM&amp;cds_page_id=247857" data-ga-event-on="click" href="https://subscribe.outsideonline.com/servlet/ConvertibleGateway?cds_mag_code=OUM&amp;cds_page_id=247857" rel="noopener" target="_blank">
# Magazine</a>
# </div>
# <span class="c-subscribe-dialog__text">Save up to 72%</span>
# </div>
# </div>
# <a class="site-header__icon site-header__icon--search js-toggle" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/search","title clicked to":"Search"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNavRight" data-ga-event-category="search" data-ga-event-label="/search" data-ga-event-on="click" data-toggled="main-container" href="/search">
# <svg height="24px" viewbox="0 0 500 500" width="24px" xmlns="http://www.w3.org/2000/svg"><title>Search Icon</title><path class="svg-fill" d="M485 420.3L367.3 302.6c17.7-29.2 28-63.4 28-100C395.2 96.2 303 4 196.6 4 90.2 4 4 90.2 4 196.6s92.2 198.6 198.6 198.6c35.4 0 68.5-9.6 97-26.2l118.3 118.3c11.6 11.6 30.4 11.6 41.9 0l29.4-29.3c11.5-11.6 7.3-26.2-4.2-37.7zM63.3 196.6C63.3 123 123 63.3 196.6 63.3c73.7 0 139.3 65.6 139.3 139.3 0 73.7-59.7 133.4-133.4 133.4-73.6 0-139.2-65.7-139.2-139.4z"></path></svg>
# </a>
# </div>
# </div>
# <nav class="site-header__exposed-nav" role="navigation">
# <div class="site-header__exposed-nav-inner">
# <ul class="site-nav__primary">
# <li class="site-nav__primary-item"><a class="site-nav__primary-link first expanded" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/outdoor-gear","title clicked to":"Gear"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="gear" data-ga-event-label="/outdoor-gear" data-ga-event-on="click" href="/outdoor-gear">Gear</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link expanded" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/outdoor-adventure","title clicked to":"Adventure"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="adventure" data-ga-event-label="/outdoor-adventure" data-ga-event-on="click" href="/outdoor-adventure">Adventure</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link expanded active-trail" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/health","title clicked to":"Health"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="health" data-ga-event-label="/health" data-ga-event-on="click" href="/health">Health</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link expanded" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/adventure-travel","title clicked to":"Travel"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="travel" data-ga-event-label="/adventure-travel" data-ga-event-on="click" href="/adventure-travel">Travel</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link expanded" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/culture","title clicked to":"Culture"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="culture" data-ga-event-label="/culture" data-ga-event-on="click" href="/culture">Culture</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/archive\/long-reads","title clicked to":"Long Reads"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="long reads" data-ga-event-label="/archive/long-reads" data-ga-event-on="click" href="/archive/long-reads">Long Reads</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link expanded" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/featured-videos","title clicked to":"Video"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="video" data-ga-event-label="/featured-videos" data-ga-event-on="click" href="/featured-videos">Video</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link expanded" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"\/podcasts","title clicked to":"Podcast"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="podcast" data-ga-event-label="/podcasts" data-ga-event-on="click" href="/podcasts">Podcast</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link last leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"top","url clicked to":"http:\/\/bit.ly\/2PKyTJX","title clicked to":"Outside Experience"}' data-amplitude-internal-source="top nav" data-ga-event-action="mainNav" data-ga-event-category="outside experience" data-ga-event-label="http://bit.ly/2PKyTJX" data-ga-event-on="click" href="https://bit.ly/2PKyTJX">Outside Experience</a></li>
# </ul>
# </div>
# </nav>
# <span class="site-header__nav-toggle js-toggle-parent" data-ga-custom-event-menu-toggle="">
# <span class="site-header__nav-x"></span>
# </span>
# <nav class="site-header__nav site-nav" role="navigation">
# <ul class="site-nav__primary">
# <li class="site-nav__primary-item"><a class="site-nav__primary-link first leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/outdoor-gear","title clicked to":"Gear"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="gear" data-ga-event-label="/outdoor-gear" data-ga-event-on="click" href="/outdoor-gear">Gear</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/outdoor-adventure","title clicked to":"Adventure"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="adventure" data-ga-event-label="/outdoor-adventure" data-ga-event-on="click" href="/outdoor-adventure">Adventure</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/health","title clicked to":"Health"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="health" data-ga-event-label="/health" data-ga-event-on="click" href="/health">Health</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/adventure-travel","title clicked to":"Travel"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="travel" data-ga-event-label="/adventure-travel" data-ga-event-on="click" href="/adventure-travel">Travel</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/culture","title clicked to":"Culture"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="culture" data-ga-event-label="/culture" data-ga-event-on="click" href="/culture">Culture</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/archive\/long-reads","title clicked to":"Long Reads"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="long reads" data-ga-event-label="/archive/long-reads" data-ga-event-on="click" href="/archive/long-reads">Long Reads</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/featured-videos","title clicked to":"Video"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="video" data-ga-event-label="/featured-videos" data-ga-event-on="click" href="/featured-videos">Video</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/podcasts","title clicked to":"Podcast"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="podcast" data-ga-event-label="/podcasts" data-ga-event-on="click" href="/podcasts">Podcast</a></li>
# <li class="site-nav__primary-item"><a class="site-nav__primary-link last leaf" data-amplitude-event="nav clicked" data-amplitude-event-properties='{"nav location":"hamburger","url clicked to":"\/magazine","title clicked to":"Magazine Archive"}' data-amplitude-internal-source="hamburger nav" data-ga-event-action="hamburgerNav" data-ga-event-category="magazine archive" data-ga-event-label="/magazine" data-ga-event-on="click" href="/magazine">Magazine Archive</a></li>
# </ul>
# </nav>
# </div>
# <div class="site-header__search-form-wrap">
# <button class="close js-toggle" data-toggled="main-container"><span class="is-vishidden">Close Search</span></button>
# <form accept-charset="UTF-8" action="/bcse/search" class="site-header__search-form" id="search-form" method="get" role="search">
# <fieldset class="site-header__search-fields">
# <label class="is-vishidden" for="edit-keys">Search</label>
# <input class="site-header__search-input" id="edit-keys" name="keys" placeholder="Search Outside" type="text"/>
# <button class="site-header__submit">Search</button>
# </fieldset>
# <div class="search__legal">
# <img alt="Bing Logo" class="search__logo" src="/sites/all/themes/outside/images/bing-logo.svg"/>
# <a class="search__privacy-link text--xs font--sans" href="https://go.microsoft.com/fwlink/?LinkId=521839" target="_blank">Microsoft Privacy Statement</a>
# </div>
# </form>
# </div>
# <div class="js-leaderboard-wrap">
# <div class="site-header__billboard-ad align-center ad-block-970x250_728x90 js-ad-responsive js-ad-refresh js-ad-sticky">
# <div class="js-ad-delay scroll-load" data-size="[[970,66],[970,90],[728,90],[970,250],[300,50],[320,50],[1,1]]" data-size-map="[[[970,0],[[970,66],[970,90],[728,90],[970,250],[1,1]]],[[728,0],[[728,90],[1,1]]],[[0,0],[[320,50],[300,50],[1,1]]]]"></div> </div>
# </div>
# </header>
# <script type="text/javascript">
# (function () {
#   // When the user scrolls down, hide the header.
#   // When the user scrolls up, show the header.
#   var prevScrollpos = window.pageYOffset,
#       siteHeader = document.querySelector('.js-site-header'),
#       bodyEl = document.querySelector('body'),
#       scrollDirection = null,
#       subscribeDialog = document.querySelector('.c-subscribe-dialog'),
#       siteHeaderHeight = siteHeader.offsetHeight;
#
#   function headerScroll() {
#     try {
#       var currentScrollPos = window.pageYOffset,
#         scrollTop = window.pageYOffset || document.documentElement.scrollTop;
#       if (scrollTop > 10) {
#         if (Math.abs(prevScrollpos - currentScrollPos) > 10) {
#           siteHeader.classList.add('is-fixed');
#           subscribeDialog.classList.remove('is-active');
#           // Trigger only with previous direction was not up.
#           if (prevScrollpos >= currentScrollPos) {
#             if (scrollDirection !== 'up') {
#               scrollDirection = 'up';
#               siteHeader.style.transform = ('translateY(0)');
#               bodyEl.classList.remove('js-scroll-dir--down');
#               bodyEl.classList.remove('js-scroll-dir--top');
#               bodyEl.classList.add('js-scroll-dir--up');
#             }
#           }
#           // Trigger only with previous direction was not down.
#           else {
#             if (scrollDirection !== 'down') {
#               scrollDirection = 'down';
#               siteHeader.style.transform = ('translateY(-' + siteHeaderHeight + 'px)');
#               bodyEl.classList.remove('js-scroll-dir--up');
#               bodyEl.classList.remove('js-scroll-dir--top');
#               bodyEl.classList.add('js-scroll-dir--down');
#             }
#           }
#         }
#       }
#       else {
#         bodyEl.classList.remove('js-scroll-dir--top');
#         bodyEl.classList.remove('js-scroll-dir--up');
#       }
#       prevScrollpos = currentScrollPos;
#     } catch (error) {
#       document.removeEventListener('scroll', headerScroll);
#       console.log(error);
#     }
#   }
#   document.addEventListener('scroll', headerScroll);
# })();
# </script>
# <div class="container-inner">
# <div class="main-content" role="main">
# <div class="wrap main-content-wrap cf">
# <div class="article__container js-article-container article-type--linear" data-ad-vars='{"account":"299403","zone":"\/299403\/outside.health\/nutrition","sub_channel":"Nutrition","sec":null,"page":"the-definitive-superfood-ranking","terms":"[\"Health\",\"Nutrition\"]","cat":"[\"food-and-drink\",\"science\"]","cluster":null,"adcat":null,"author":"AC Shilton","content_type":"article_infinite_stack","hierarchy":"\/health\/nutrition\/the-definitive-superfood-ranking\/","companion":"false","preroll":"true","content_issue":"Outside Online","created":"2016-10-31T01:00:00-05:00","changed":"2019-07-24T16:33:33-05:00","node_id":"2128816","word_count":null,"affiliate_native":"not_applicable","disable_ads":"false","editor":null}' data-amplitude-vars='{"author":"AC Shilton","category":["Food and Drink","Science"],"magazine issue":"Outside Online","contains affiliate":false,"is native":false,"word count":2397,"average read time minutes":11,"average read time seconds":639,"character count":15107,"is stack":true,"page title":"The Definitive Superfood Ranking","page nid":"2128816","publish date":"2016-10-31","content type":"article","placement":["Nutrition","Health"],"channel name":"Health","url":"\/2128816\/definitive-superfood-ranking","api_key":"d14e9390e0d6d31e46c5b5b09539ad0d"}' data-url="/2128816/definitive-superfood-ranking" id="article-2128816">
# <div class="breadcrumbs article-origin"><a data-amplitude-internal-source="breadcrumb" data-ga-event-action="breadcrumb_click" data-ga-event-category="breadcrumb" data-ga-event-label="health" data-ga-event-on="click" href="/health">Health</a><a data-amplitude-internal-source="breadcrumb" data-ga-event-action="breadcrumb_click" data-ga-event-category="breadcrumb" data-ga-event-label="health/nutrition" data-ga-event-on="click" href="/health/nutrition">Nutrition</a></div>
# <article class="article linear-article sticky-parent article--no-img" data-ad-vars='{"account":"299403","zone":"\/299403\/outside.health\/nutrition","sub_channel":"Nutrition","sec":null,"page":"the-definitive-superfood-ranking","terms":"[\"Health\",\"Nutrition\"]","cat":"[\"food-and-drink\",\"science\"]","cluster":null,"adcat":null,"author":"AC Shilton","content_type":"article_infinite_stack","hierarchy":"\/health\/nutrition\/the-definitive-superfood-ranking\/","companion":"false","preroll":"true","content_issue":"Outside Online","created":"2016-10-31T01:00:00-05:00","changed":"2019-07-24T16:33:33-05:00","node_id":"2128816","word_count":null,"affiliate_native":"not_applicable","disable_ads":"false","editor":null}' data-url="/2128816/definitive-superfood-ranking" id="linear-article-2128816">
# <header class="article__header">
# <div class="article__hgroup">
# <h1 class="article__title heading__one js-article-title">The Definitive Superfood Ranking</h1>
# <h2 class="article__subtitle subtitle">It seems like everything in the grocery store is labeled "super." We dove into which foods are actually proven, by science, to be good for you and which ones are all hype.</h2>
# </div>
# </header>
# <div class="article__hero enlarge js-open-modal" data-modal-img-src="https://www.outsideonline.com/sites/default/files/styles/img_1400x800/public/2016/10/24/superfood-matrix_h.jpg?itok=PNP1ddMP">
# <div class="article__photo-meta">
# <span class="article__caption">Superfoods are a tricky business. </span> <span class="article__credit">(<em>Photo: </em>Nick Kelley)</span> </div>
# <div class="article__hero-image article__hero-image--has-blur">
# <picture>
# <!--[if IE 9]><video style="display: none;"><![endif]-->
# <source data-srcset="https://www.outsideonline.com/sites/default/files/styles/width_1200/public/2016/10/24/superfood-matrix_h.jpg?itok=F9Qr94R1" media="(min-width: 800px)" srcset="https://www.outsideonline.com/sites/default/files/styles/width_1200-low-quality/public/2016/10/24/superfood-matrix_h.jpg?itok=OLLysqQx">
# <source data-srcset="https://www.outsideonline.com/sites/default/files/styles/img_850x510/public/2016/10/24/superfood-matrix_h.jpg?itok=UMse2Fcv" media="(min-width: 600px)" srcset="https://www.outsideonline.com/sites/default/files/styles/img_850x510-low-quality/public/2016/10/24/superfood-matrix_h.jpg?itok=BKqKPjCw">
# <!--[if IE 9]></video><![endif]-->
# <img alt="Superfoods are a tricky business. " class="lazy" data-original="https://www.outsideonline.com/sites/default/files/styles/img_600x600/public/2016/10/24/superfood-matrix_s.jpg?itok=34_3Hlmd" src="https://www.outsideonline.com/sites/default/files/styles/img_600x600-low-quality/public/2016/10/24/superfood-matrix_s.jpg?itok=7bGiXdyj"/>
# </source></source></picture>
# </div>
# </div>
# <div class="article__content sticky-parent">
# <div class="article__meta">
# <div class="article__author font--sans text--xs"><strong><div class="article__author-image rounded no-print"><a class="author-link link--black lazy" data-bg="https://www.outsideonline.com/sites/default/files/styles/thumbnail/public/2017/08/15/ac-shilton-bio-portrait_s.jpg?itok=6Bf1Y7N9" href="/1747596/ac-shilton"><span class="is-vishidden">AC Shilton</span></a></div><a class="link--black" href="/1747596/ac-shilton"><span itemprop="author" itemtype="https://schema.org/Person"><span itemprop="name">AC Shilton</span></span></a></strong></div>
# <hr/>
# <div class="article__date font--sans text--xs gray--dark"><span content="2016-10-31T01:00:00-05:00" datatype="xsd:dateTime" property="dc:date dc:created">Oct 31, 2016</span></div>
# </div>
# <div class="article__body-wrap">
# <div class="article-share share-toolbox no-print share-toolbox--vert">
# <div class="share-toolbox__inner spacing--quarter">
# <div class="share-buttons">
# <a aria-label="facebook share" class="share-button__link share-button__link--facebook" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"Facebook","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="Facebook" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="Facebook" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" href="https://facebook.com/sharer/sharer.php?u=https%3A//www.outsideonline.com/2128816/definitive-superfood-ranking%3Futm_medium%3Dsocial%26utm_source%3Dfacebook%26utm_campaign%3Donsiteshare" rel="noopener" target="_blank">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg enable-background="new 0 0 24 24" height="24px" id="facebook-ico" version="1.1" viewbox="0 0 24 24" width="24px" x="0px" xml:space="preserve" y="0px"><title>Facebook Icon</title><g><path class="svg-fill" d="M18.768,7.465H14.5V5.56c0-0.896,0.594-1.105,1.012-1.105s2.988,0,2.988,0V0.513L14.171,0.5C10.244,0.5,9.5,3.438,9.5,5.32 v2.145h-3v4h3c0,5.212,0,12,0,12h5c0,0,0-6.85,0-12h3.851L18.768,7.465z"></path></g></svg>
# </div>
# <span class="share-button__title">Share</span>
# </div>
# </a>
# <a aria-label="twitter share" class="share-button__link share-button__link--twitter" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"Twitter","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="Twitter" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="Twitter" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" href="https://twitter.com/intent/tweet/?text=The%20Definitive%20Superfood%20Ranking @outsidemagazine&amp;url=https%3A//www.outsideonline.com/2128816/definitive-superfood-ranking%3Futm_medium%3Dsocial%26utm_source%3Dtwitter%26utm_campaign%3Donsiteshare" rel="noopener" target="_blank">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg enable-background="new 0 0 24 24" height="24px" id="twitter-ico" version="1.1" viewbox="0 0 24 24" width="24px" x="0px" xml:space="preserve" y="0px"><title>Twitter Icon</title><g><path class="svg-fill" d="M23.444,4.834c-0.814,0.363-1.5,0.375-2.228,0.016c0.938-0.562,0.981-0.957,1.32-2.019c-0.878,0.521-1.851,0.9-2.886,1.104 C18.823,3.053,17.642,2.5,16.335,2.5c-2.51,0-4.544,2.036-4.544,4.544c0,0.356,0.04,0.703,0.117,1.036 C8.132,7.891,4.783,6.082,2.542,3.332C2.151,4.003,1.927,4.784,1.927,5.617c0,1.577,0.803,2.967,2.021,3.782 C3.203,9.375,2.503,9.171,1.891,8.831C1.89,8.85,1.89,8.868,1.89,8.888c0,2.202,1.566,4.038,3.646,4.456 c-0.666,0.181-1.368,0.209-2.053,0.079c0.579,1.804,2.257,3.118,4.245,3.155C5.783,18.102,3.372,18.737,1,18.459 C3.012,19.748,5.399,20.5,7.966,20.5c8.358,0,12.928-6.924,12.928-12.929c0-0.198-0.003-0.393-0.012-0.588 C21.769,6.343,22.835,5.746,23.444,4.834z"></path></g></svg>
# </div>
# <span class="share-button__title">Tweet</span>
# </div>
# </a>
# <a aria-label="sms share" class="share-button__link share-button__link--sms" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"SMS","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="SMS" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="SMS" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" displaytext="SMS" st_nid="2128816" st_title="The Definitive Superfood Ranking" st_url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" target="_self">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg id="sms-ico" viewbox="0 0 58 58" xmlns="http://www.w3.org/2000/svg"><title>sms</title><path class="svg-fill" d="M29,3.37C13.4,3.37.67,13.63.67,26.2c0,7.5,4.51,14.18,11.5,18.33a19.85,19.85,0,0,1-5.24,7.06A1.25,1.25,0,0,0,6.64,53a1.27,1.27,0,0,0,1.09.73h.14A30.67,30.67,0,0,0,22,48.32,36.67,36.67,0,0,0,29,49c15.63,0,28.36-10.25,28.36-22.84S44.68,3.37,29,3.37Zm-14.69,28a4.8,4.8,0,1,1,4.8-4.8,4.8,4.8,0,0,1-4.8,4.8Zm15.13,0a4.8,4.8,0,1,1,4.8-4.8,4.8,4.8,0,0,1-4.8,4.8h0Zm15.06-.22a4.8,4.8,0,1,1,4.8-4.8h0a4.8,4.8,0,0,1-4.79,4.8h0Z" fill="#fff"></path></svg>
# </div>
# <span class="share-button__title">Text</span>
# </div>
# </a>
# <a aria-label="email share" class="share-button__link share-button__link--email" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"Email","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="Email" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="Email" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" href="mailto:?subject=The%20Definitive%20Superfood%20Ranking&amp;body=https%3A//www.outsideonline.com/2128816/definitive-superfood-ranking%3Futm_medium%3Dsocial%26utm_source%3Demail%26utm_campaign%3Donsiteshare" target="_blank">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg id="email-ico" viewbox="0 0 58 58" xmlns="http://www.w3.org/2000/svg"><title>email</title><path class="svg-fill" d="M53.36,51.3H6.46L6,51.21a5.12,5.12,0,0,1-4.16-5c0-8.15,0-16.31,0-24.47,0-.09,0-.18,0-.27l.07-.05a.88.88,0,0,0,.1.17,18.5,18.5,0,0,0,1.8,1.64c1.46,1.07,3,2.08,4.45,3.11q6.6,4.61,13.19,9.24a24.41,24.41,0,0,0,5.31,3,8.27,8.27,0,0,0,6,.13,21.35,21.35,0,0,0,5-2.66q7.86-5.52,15.76-11a27.89,27.89,0,0,0,3.76-2.87c.26-.26.52-.5.81-.78v25a5,5,0,0,1-3.88,4.77C53.86,51.21,53.61,51.26,53.36,51.3Z" fill="#fff"></path><path class="svg-fill" d="M29.85,7.13H52.73a5,5,0,0,1,4.84,3,5.51,5.51,0,0,1,.24,3.66,9.93,9.93,0,0,1-2.36,4.39,18.42,18.42,0,0,1-3.71,3.17C46.15,25.24,40.58,29.14,35,33a16.09,16.09,0,0,1-3.24,1.83,5,5,0,0,1-4-.1,22.83,22.83,0,0,1-3.71-2.21L8.66,21.77a21.46,21.46,0,0,1-3.71-3A13.68,13.68,0,0,1,2.3,15a6.15,6.15,0,0,1,.37-5.63A4.34,4.34,0,0,1,6.6,7.14H29.85Z" fill="#fff"></path></svg>
# </div>
# <span class="share-button__title">Email</span>
# </div>
# </a>
# </div>
# </div>
# <span class="share-toggle js-toggle-parent"></span>
# </div>
# <div class="article__body js-article-body article__body--linear post-entry spacing has-dropcap">
# <div class="article__right-rail no-print">
# <div class="article__ad">
# <div class="js-ad scroll-load" data-size="[300,250]" data-viewport="large"></div> </div>
# <div class="article__ad ad-block--sticky-fadein js-ad-300x600-sticky">
# <div class="js-ad scroll-load" data-size="[[300,600],[300,250],[160,600]]" data-viewport="large"></div> </div>
# </div>
# ...
# </div>
# <a class="recirc__btn btn btn--l" data-amplitude-internal-source="recirculation" data-ga-event-action="click" data-ga-event-category="recirc_bottom_button" data-ga-event-label="/fitness" data-ga-event-on="click" href="/fitness">More Health</a> </section>
# </article></div>
# <div class="js-read-next align-center no-print">
# <a class="btn load-more" data-articles='["2407527","2407794","2407107","2406912","2407098","2406182","2405580","2404367","2405005","2404328"]' data-term-link="/health/nutrition" data-this-nid="2128816" href="/2407527/elimination-diets-and-athletes-need-to-know" id="next_article"><span class="icon-reload"></span> See More</a>
# </div>
# <div class="newsletter-block--linear js-newsletter-block no-print">
# <div class="newsletter-block js-newsletter-block no-print" data-title="Bodywork">
# <div class="js-hide-success"><h3 class="newsletter-block__title heading__two">Get stronger. Get smarter. Get Outside's health newsletter twice a week.</h3></div>
# <form accept-charset="UTF-8" action="/2128816/definitive-superfood-ranking" data-js-ajax-form="" id="outside-newsletter-inline-signup-form" method="post"><div><input name="cm-f-bilthd" type="hidden" value="article_inline-signup_health-archive"/>
# <input name="cm-sub" type="hidden" value="08e74d0908a159d0020dd189d593077c"/>
# <input name="cm-name" type="hidden" value="Bodywork"/>
# <div class="newsletter-block__group"><input aria-label="Email Address" class="newsletter-block__input form-text" id="edit-cm-mquuy-mquuy" maxlength="128" name="cm-mquuy-mquuy" placeholder="Enter your email address" size="60" type="text" value=""/><input id="cm-recaptcha" name="cm-recaptcha" type="hidden" value=""/>
# <input class="newsletter-block__submit js-newsletter-block__submit btn btn-submit form-submit" id="edit-submit" name="op" type="submit" value="Get It"/></div><div class="recaptcha-message font--sans">This site is protected by reCAPTCHA and the Google <a class="link--red" href="https://policies.google.com/privacy" target="_blank">Privacy Policy</a> and <a class="link--red" href="https://policies.google.com/terms" target="_blank">Terms of Service</a> apply.</div><div id="recaptcha"></div><input name="form_build_id" type="hidden" value="form-IwOIT8jeBbMiZp8HbzCiFaRGv_51b4iNpQOt1wfTmyc"/>
# <input name="form_id" type="hidden" value="outside_newsletter_inline_signup_form"/>
# </div></form></div>
# <a class="dn" data-amplitude-event="newsletter subscribed" data-ga-event-on="click" id="js-newsletter-subscribe-tracking"></a>
# </div>
# </div>
# <div class="article-share share-toolbox no-print article-social--bottom article-social--right">
# <div class="share-toolbox__inner spacing--quarter">
# <div class="share-buttons">
# <a aria-label="facebook share" class="share-button__link share-button__link--facebook" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"Facebook","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="Facebook" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="Facebook" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" href="https://facebook.com/sharer/sharer.php?u=https%3A//www.outsideonline.com/2128816/definitive-superfood-ranking%3Futm_medium%3Dsocial%26utm_source%3Dfacebook%26utm_campaign%3Donsiteshare" rel="noopener" target="_blank">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg enable-background="new 0 0 24 24" height="24px" version="1.1" viewbox="0 0 24 24" width="24px" x="0px" xml:space="preserve" y="0px"><use xlink:href="#facebook-ico"></use></svg>
# </div>
# <span class="share-button__title">Share</span>
# </div>
# </a>
# <a aria-label="twitter share" class="share-button__link share-button__link--twitter" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"Twitter","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="Twitter" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="Twitter" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" href="https://twitter.com/intent/tweet/?text=The%20Definitive%20Superfood%20Ranking @outsidemagazine&amp;url=https%3A//www.outsideonline.com/2128816/definitive-superfood-ranking%3Futm_medium%3Dsocial%26utm_source%3Dtwitter%26utm_campaign%3Donsiteshare" rel="noopener" target="_blank">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg enable-background="new 0 0 24 24" height="24px" version="1.1" viewbox="0 0 24 24" width="24px" x="0px" xml:space="preserve" y="0px"><use xlink:href="#twitter-ico"></use></svg>
# </div>
# <span class="share-button__title">Tweet</span>
# </div>
# </a>
# <a aria-label="sms share" class="share-button__link share-button__link--sms" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"SMS","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="SMS" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="SMS" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" displaytext="SMS" st_nid="2128816" st_title="The Definitive Superfood Ranking" st_url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" target="_self">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg enable-background="new 0 0 24 24" height="24px" version="1.1" viewbox="0 0 24 24" width="24px" x="0px" xml:space="preserve" y="0px"><use xlink:href="#sms-ico"></use></svg>
# </div>
# <span class="share-button__title">Text</span>
# </div>
# </a>
# <a aria-label="email share" class="share-button__link share-button__link--email" data-amplitude-event="content shared" data-amplitude-event-properties='{"share type":"Email","share url":"https:\/\/www.outsideonline.com\/2128816\/definitive-superfood-ranking","share title":"The Definitive Superfood Ranking","share nid":"2128816"}' data-ga-event-action="Email" data-ga-event-category="outside_share" data-ga-event-label="https://www.outsideonline.com/2128816/definitive-superfood-ranking" data-ga-event-on="click" data-share-type="Email" data-share-url="https://www.outsideonline.com/2128816/definitive-superfood-ranking" href="mailto:?subject=The%20Definitive%20Superfood%20Ranking&amp;body=https%3A//www.outsideonline.com/2128816/definitive-superfood-ranking%3Futm_medium%3Dsocial%26utm_source%3Demail%26utm_campaign%3Donsiteshare" target="_blank">
# <div class="share-button share-button--small">
# <div aria-hidden="true" class="share-button__icon path-fill--white">
# <svg enable-background="new 0 0 24 24" height="24px" version="1.1" viewbox="0 0 24 24" width="24px" x="0px" xml:space="preserve" y="0px"><use xlink:href="#email-ico"></use></svg>
# </div>
# <span class="share-button__title">Email</span>
# </div>
# </a>
# </div>
# </div>
# <span class="share-toggle js-toggle-parent"></span>
# </div>
# </div>
# </div>
# <footer class="footer js-footer no-print" role="contentinfo">
# <div class="footer__graphic"></div>
# <div class="footer__wrap">
# <div class="footer__inner">
# <a class="footer__logo no-hover" href="/"><img alt="Outside Online" src="/sites/all/themes/outside/images/outside-o.svg"/></a>
# <div class="footer__mission">
# <h4 class="footer__mission-heading"><strong>Our Mission</strong></h4>
# <p class="footer__mission-text">To inspire active participation in the world outside through award-winning coverage of the sports, people, places, adventure, discoveries, health and fitness, gear and apparel, trends and events that make up an active lifestyle.</p>
# </div>
# <div class="footer__social">
# <a class="footer__social-item footer__social--facebook" href="https://www.facebook.com/outsidemagazine"><svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><title>Facebook Icon</title><path class="svg-fill" d="M294.51,509.5V256h68.84l9-87.34H294.51l.12-43.73c0-22.83,2.16-35.08,34.36-35.08h43V2.5H303c-82.78,0-111.85,42.41-111.85,113.65v52.38H139.64V256H191.3V509.5Z" fill="#231f20"></path></svg>
# </a>
# <a class="footer__social-item footer__social--twitter" href="https://twitter.com/outsidemagazine"><svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><title>Twitter Icon</title><path class="svg-fill" d="M248.63,158.41l1.08,18-18.23-2.16C165,165.73,107,136.95,57.58,88.74l-24.11-24L27.24,82.38C14,121.84,22.44,163.57,49.91,191.51,64.42,207,61.18,209.26,36,200c-8.75-2.88-16.43-5.16-17.15-4.08-2.52,2.64,6.24,36.1,13.19,49.41,9.47,18.47,28.9,36.46,50.13,47.25L100,301l-21.23.36c-20.51,0-21.23.36-18.95,8.16,7.32,24,36.22,49.41,68.36,60.44l22.67,7.68L131.1,389.4a206.11,206.11,0,0,1-97.86,27.22c-16.43.36-30,1.8-30,3,0,3.72,44.61,24.35,70.52,32.5,77.83,24,170.18,13.67,239.62-27.34C362.68,395.63,412,337.71,435,281.7c12.35-29.86,24.83-84.43,24.83-110.57,0-16.91,1.08-19.19,21.59-39.46C493.53,119.92,504.8,107,507,103.25c3.6-7,3.24-7-15.35-.72-31.06,11-35.5,9.59-20.15-7,11.39-11.87,24.83-33.22,24.83-39.46,0-1.08-5.52.72-11.63,4.08-6.6,3.72-21.23,9.23-32.14,12.59L432.72,79,414.85,66.79c-9.83-6.6-23.75-14-31.06-16.19-18.59-5.16-47.13-4.44-63.92,1.44C274.18,68.83,245.39,111.52,248.63,158.41Z" fill="#231f20"></path></svg>
# </a>
# <a class="footer__social-item footer__social--instagram" href="https://instagram.com/outsidemagazine"><svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><title>Instagram Icon</title><path class="svg-fill" d="M256,49.47c67.27,0,75.23.26,101.8,1.47,24.56,1.12,37.9,5.22,46.78,8.67a78.05,78.05,0,0,1,29,18.84,78.05,78.05,0,0,1,18.84,29c3.45,8.88,7.55,22.22,8.67,46.78,1.21,26.56,1.47,34.53,1.47,101.8s-.26,75.23-1.47,101.8c-1.12,24.56-5.22,37.9-8.67,46.78a83.43,83.43,0,0,1-47.81,47.81c-8.88,3.45-22.22,7.55-46.78,8.67-26.56,1.21-34.53,1.47-101.8,1.47s-75.24-.26-101.8-1.47c-24.56-1.12-37.9-5.22-46.78-8.67a78.05,78.05,0,0,1-29-18.84,78.05,78.05,0,0,1-18.84-29c-3.45-8.88-7.55-22.22-8.67-46.78-1.21-26.56-1.47-34.53-1.47-101.8s.26-75.23,1.47-101.8c1.12-24.56,5.22-37.9,8.67-46.78a78.05,78.05,0,0,1,18.84-29,78.05,78.05,0,0,1,29-18.84c8.88-3.45,22.22-7.55,46.78-8.67,26.56-1.21,34.53-1.47,101.8-1.47m0-45.39c-68.42,0-77,.29-103.87,1.52S107,11.08,91,17.31A123.49,123.49,0,0,0,46.36,46.36,123.49,123.49,0,0,0,17.31,91C11.08,107,6.82,125.32,5.6,152.13S4.08,187.58,4.08,256s.29,77,1.52,103.87S11.08,405,17.31,421a123.49,123.49,0,0,0,29.06,44.62A123.49,123.49,0,0,0,91,494.7c16,6.23,34.34,10.49,61.15,11.71s35.45,1.52,103.87,1.52,77-.29,103.87-1.52S405,500.92,421,494.7A128.82,128.82,0,0,0,494.7,421c6.23-16,10.49-34.34,11.71-61.15s1.52-35.45,1.52-103.87-.29-77-1.52-103.87S500.92,107,494.7,91a123.49,123.49,0,0,0-29.06-44.62A123.49,123.49,0,0,0,421,17.31C405,11.08,386.68,6.82,359.87,5.6S324.42,4.08,256,4.08Z" fill="#231f20"></path><path class="svg-fill" d="M256,126.64A129.36,129.36,0,1,0,385.36,256,129.36,129.36,0,0,0,256,126.64ZM256,340a84,84,0,1,1,84-84A84,84,0,0,1,256,340Z" fill="#231f20"></path><circle class="svg-fill" cx="390.48" cy="121.52" fill="#231f20" r="30.23"></circle></svg>
# </a>
# <a class="footer__social-item footer__social--pinterest" href="https://pinterest.com/outsidemagazine/"><svg viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><title>Pinterest Icon</title><path class="svg-fill" d="M65.75,184.36c0,50.16,18.46,94.76,57.94,111.55,6.45,2.78,12.35.11,14.12-7.34,1.22-5.12,4.45-18.13,5.78-23.47,2-7.34,1.11-9.9-4.12-16.24-11.34-13.79-18.68-31.81-18.68-57.28,0-73.74,53.38-139.69,139.13-139.69,76,0,117.67,47.82,117.67,111.77,0,84.08-36.15,155.15-89.64,155.15-29.58,0-51.72-25.25-44.6-56.16,8.45-36.92,25-76.85,25-103.43,0-23.91-12.46-43.82-38.15-43.82-30.25,0-54.5,32.25-54.5,75.52,0,27.58,9,46.27,9,46.27s-30.81,135-36.26,158.71c-10.79,47.16-1.67,105-.78,110.77a3.81,3.81,0,0,0,6.78,1.78c2.78-3.67,38.81-49.6,50.94-95.42,3.45-12.9,19.91-80.19,19.91-80.19,9.9,19.24,38.59,36.37,69.07,36.37,91,0,152.59-85.53,152.59-200C447,82.71,375.93,2.08,268.05,2.08,133.59,2.08,65.75,101.51,65.75,184.36Z" fill="#231f20"></path></svg>
# </a>
# </div>
# <nav class="footer__nav">
# <ul class="footer__nav-list">
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/about" title="">About</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="https://outsidemag.s3.amazonaws.com/mediakit/2020OutsideMediaKit-010920.pdf" title="">Media Kit</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/2060751/careers-outside" title="">Careers</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="https://w1.buysub.com/pubs/MD/OUM/login_singlemag.jsp?cds_page_id=82339&amp;cds_mag_code=OUM&amp;id=1563495367131&amp;lsid=91991916071011180&amp;vid=1" title="">Subscribers</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/2171581/outside-onlines-policy-affiliate-links" title="">Affiliate</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/1824056/outsides-rss-feeds" title="">RSS</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/2271831/give-us-your-feedback" title="">Feedback</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/2063191/newsletter-signup" title="">Newsletters</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/sitemap" title="">Sitemap</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/1929491/about-our-ads" title="">About Our Ads</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/1929046/outside-terms-use-and-end-user-license-agreement" title="">Terms and Conditions</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/2406913/do-not-sell-my-personal-information" title="">Do Not Sell My Personal Information</a></li>
# <li class="footer__nav-item"><a class="footer__nav-link" data-amplitude-internal-source="footer" href="/2408724/outside-integrated-media-llcs-privacy-policy" title="">Privacy Policy</a></li>
# </ul>
# </nav>
# <div class="copyright">© 2020 Outside Integrated Media, LLC</div>
# </div>
# </div>
# </footer>
# </div>
# <script src="https://www.outsideonline.com/sites/default/files/js/js_fL1Z8y0SHp3a_VTmzP3x3f8bh9MkjWiJEyhusUjl6ws.js" type="text/javascript"></script>
# </body>
# </html>

# %%
table = soup.find_all(('h2'))
table[1]
# Out:
# <h2>21. Gluten-Free Flours</h2>

# %%
ranking = []
for item in soup.find_all(('h2')):
    x = item.text
    y = ' '.join(re.findall('[A-z]/d+', x))
    ranking.append(x)
ranking
# Out:
# ['It seems like everything in the grocery store is labeled "super." We dove into which foods are actually proven, by science, to be good for you and which ones are all hype.',
#  '21. Gluten-Free Flours',
#  '20. Orange Juice',
#  '19. Coconut Oil',
#  '18. Chia Seeds',
#  '17. Kimchi',
#  '16. Sweet Potatoes',
#  '15. Almonds',
#  '14. Beets',
#  '13. Acai',
#  '12. Eggs',
#  '11. Tart Cherry Juice',
#  '10. Broccoli',
#  '9. Coffee',
#  '8. Apples',
#  '\u200b7. Green Tea',
#  '6. Black Beans',
#  '5. Dark Chocolate',
#  '4. Red Wine',
#  '3. Salmon',
#  '2. Turmeric',
#  '1. Blueberries']

# %%
tablep = soup.find_all(('p'))
tablep[3]
# Out:
# <p>The trick is knowing how to separate the good stuff from the chaff. With that in mind, we asked a few dietitians and researchers to help us rank some of this decade’s buzziest ingredients. Consider this your license to stop choking down kimchi and gluten-free bread and start hitting the blueberries and red wine hard.</p>
