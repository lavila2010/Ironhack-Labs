# %%
import pandas as pd

# %%
data= pd.read_csv('C:/Users/leandro/Desktop/Data3.csv', error_bad_lines=False)
# Out:
# b'Skipping line 16: expected 13 fields, saw 23\nSkipping line 31: expected 13 fields, saw 23\nSkipping line 45: expected 13 fields, saw 23\nSkipping line 59: expected 13 fields, saw 23\nSkipping line 68: expected 13 fields, saw 23\nSkipping line 77: expected 13 fields, saw 23\nSkipping line 99: expected 13 fields, saw 23\nSkipping line 110: expected 13 fields, saw 23\nSkipping line 121: expected 13 fields, saw 14\nSkipping line 127: expected 13 fields, saw 24\nSkipping line 139: expected 13 fields, saw 23\nSkipping line 161: expected 13 fields, saw 23\nSkipping line 167: expected 13 fields, saw 23\nSkipping line 169: expected 13 fields, saw 25\nSkipping line 171: expected 13 fields, saw 23\nSkipping line 172: expected 13 fields, saw 27\nSkipping line 174: expected 13 fields, saw 23\nSkipping line 175: expected 13 fields, saw 27\nSkipping line 176: expected 13 fields, saw 27\nSkipping line 179: expected 13 fields, saw 23\nSkipping line 184: expected 13 fields, saw 23\nSkipping line 18
# ...

# %%
data.shape
# Out:
# (620, 13)
